# %%
#!pip install roboflow

# %%
#!pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="x9Y0DtJhpAkB91rQsKIg")
project = rf.workspace("new-workspace-qfcus").project("le2i")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Le2i-2 to yolov8:: 100%|█| 167414/167414 [00:
# Extracting Dataset Version Zip to Le2i-2 in yolov8:: 100%|█| 15676/15676 [00:01<
